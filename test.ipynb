# %%
import pandas as pd
import os
dataPath=r"./data/"
__dataList = os.listdir(dataPath)   # data file names
print(__dataList)

# %%
dataList=[pd.read_csv(dataPath+data) for data in __dataList]
set = pd.concat(dataList,ignore_index=True)
print(set.head())
print(set.tail())

# %%
inputs = {'input_ids':123,'attention_mask': 123123,'labels':111}
print(inputs)
print(**inputs)
# Out:
# {'input_ids': 123, 'attention_mask': 123123, 'labels': 111}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e40465c3763a> in <module>
#       1 inputs = {'input_ids':123,'attention_mask': 123123,'labels':111}
#       2 print(inputs)
# ----> 3 print(**inputs)
#
# TypeError: 'input_ids' is an invalid keyword argument for print()

# %%
a=[1,2,3,4,5]
b=a[::-1]

# %%
# Out:
# [5, 4, 3, 2, 1]
